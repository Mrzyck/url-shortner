# %%
import pyshorteners
url = input("Enter your url: ")
print("Your url: ", pyshorteners.Shortener().tinyurl.short(url))
# Out:
# Enter your url: https://inuaye.com.ng
# Your url:  https://tinyurl.com/29c6a6d6
